# %%
#https://medium.com/geekculture/how-to-execute-a-rest-api-call-on-apache-spark-the-right-way-in-python-4367f2740e78
import requests
import json
from pyspark.sql import *
from pyspark.context import SparkContext, SparkConf

conf = SparkConf().setAppName('learning-pyspark').setMaster('local[4]') 
sc = SparkContext.getOrCreate(conf) 
    
def executeRestApi(verb, url, headers, body):
    #
    headers = {
      'content-type': "application/json"
    }

    res = None
    # Make API request, get response object back, create dataframe from above schema.
    try:
        if verb == "get":
            res = requests.get(url, data=body, headers=headers)
        else:
            res = requests.post(url, data=body, headers=headers)
            requests.get(api)
    except Exception as e:
        return e
    
    if res != None  and res.status_code == 200: # all ok
        return json.loads(res.content)
    return None

url = 'https://www.airquality.dli.mlsi.gov.cy/all_stations_data_PM'
json_txt = executeRestApi("get", url, None, None)

df = spark.read.json(sc.parallelize([json_txt]))
json_schema = df.schema
df.printSchema()
# Out:
# root
#  |-- data: struct (nullable = true)
#  |    |-- station_1: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_20: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_10: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_20: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_11: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_12: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_13: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_2: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_3: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_5: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_7: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_10: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_20: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_7: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_8: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_20: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_5: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_6001: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |    |-- station_9: struct (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- name_el: string (nullable = true)
#  |    |    |-- name_en: string (nullable = true)
#  |    |    |-- pollutants: struct (nullable = true)
#  |    |    |    |-- date_time: string (nullable = true)
#  |    |    |    |-- pollutant_1: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_20: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_38: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_8: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- pollutant_9: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- notation: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- type_el: string (nullable = true)
#  |    |    |-- type_en: string (nullable = true)
#  |-- method: string (nullable = true)

# %%
df.select('data').columns
# Out:
# ['data']

# %%
#https://stackoverflow.com/questions/38753898/how-to-flatten-a-struct-in-a-spark-dataframe
import pyspark.sql.functions as F

def flatten_df(nested_df):
    flat_cols = [c[0] for c in nested_df.dtypes if c[1][:6] != 'struct']
    nested_cols = [c[0] for c in nested_df.dtypes if c[1][:6] == 'struct']
    #print(nested_cols)
    flat_df = nested_df.select(flat_cols +
                               [F.col(nc+'.'+c).alias(nc+'_'+c)
                                for nc in nested_cols
                                for c in nested_df.select(nc+'.*').columns])
    return flat_df

d = flatten_df(df)
d = flatten_df(d)
d = flatten_df(d)
#d = flatten_df(d)
d.printSchema()
# Out:
# root
#  |-- method: string (nullable = true)
#  |-- data_station_1_latitude: string (nullable = true)
#  |-- data_station_1_longitude: string (nullable = true)
#  |-- data_station_1_name_el: string (nullable = true)
#  |-- data_station_1_name_en: string (nullable = true)
#  |-- data_station_1_type_el: string (nullable = true)
#  |-- data_station_1_type_en: string (nullable = true)
#  |-- data_station_10_latitude: string (nullable = true)
#  |-- data_station_10_longitude: string (nullable = true)
#  |-- data_station_10_name_el: string (nullable = true)
#  |-- data_station_10_name_en: string (nullable = true)
#  |-- data_station_10_type_el: string (nullable = true)
#  |-- data_station_10_type_en: string (nullable = true)
#  |-- data_station_11_latitude: string (nullable = true)
#  |-- data_station_11_longitude: string (nullable = true)
#  |-- data_station_11_name_el: string (nullable = true)
#  |-- data_station_11_name_en: string (nullable = true)
#  |-- data_station_11_type_el: string (nullable = true)
#  |-- data_station_11_type_en: string (nullable = true)
#  |-- data_station_12_latitude: string (nullable = true)
#  |-- data_station_12_longitude: string (nullable = true)
#  |-- data_station_12_name_el: string (nullable = true)
#  |-- data_station_12_name_en: string (nullable = true)
#  |-- data_station_12_type_el: string (nullable = true)
#  |-- data_station_12_type_en: string (nullable = true)
#  |-- data_station_13_latitude: string (nullable = true)
#  |-- data_station_13_longitude: string (nullable = true)
#  |-- data_station_13_name_el: string (nullable = true)
#  |-- data_station_13_name_en: string (nullable = true)
#  |-- data_station_13_type_el: string (nullable = true)
#  |-- data_station_13_type_en: string (nullable = true)
#  |-- data_station_2_latitude: string (nullable = true)
#  |-- data_station_2_longitude: string (nullable = true)
#  |-- data_station_2_name_el: string (nullable = true)
#  |-- data_station_2_name_en: string (nullable = true)
#  |-- data_station_2_type_el: string (nullable = true)
#  |-- data_station_2_type_en: string (nullable = true)
#  |-- data_station_3_latitude: string (nullable = true)
#  |-- data_station_3_longitude: string (nullable = true)
#  |-- data_station_3_name_el: string (nullable = true)
#  |-- data_station_3_name_en: string (nullable = true)
#  |-- data_station_3_type_el: string (nullable = true)
#  |-- data_station_3_type_en: string (nullable = true)
#  |-- data_station_5_latitude: string (nullable = true)
#  |-- data_station_5_longitude: string (nullable = true)
#  |-- data_station_5_name_el: string (nullable = true)
#  |-- data_station_5_name_en: string (nullable = true)
#  |-- data_station_5_type_el: string (nullable = true)
#  |-- data_station_5_type_en: string (nullable = true)
#  |-- data_station_7_latitude: string (nullable = true)
#  |-- data_station_7_longitude: string (nullable = true)
#  |-- data_station_7_name_el: string (nullable = true)
#  |-- data_station_7_name_en: string (nullable = true)
#  |-- data_station_7_type_el: string (nullable = true)
#  |-- data_station_7_type_en: string (nullable = true)
#  |-- data_station_8_latitude: string (nullable = true)
#  |-- data_station_8_longitude: string (nullable = true)
#  |-- data_station_8_name_el: string (nullable = true)
#  |-- data_station_8_name_en: string (nullable = true)
#  |-- data_station_8_type_el: string (nullable = true)
#  |-- data_station_8_type_en: string (nullable = true)
#  |-- data_station_9_latitude: string (nullable = true)
#  |-- data_station_9_longitude: string (nullable = true)
#  |-- data_station_9_name_el: string (nullable = true)
#  |-- data_station_9_name_en: string (nullable = true)
#  |-- data_station_9_type_el: string (nullable = true)
#  |-- data_station_9_type_en: string (nullable = true)
#  |-- data_station_1_pollutants_date_time: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_20: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_1_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_date_time: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_20: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_10_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_date_time: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_11_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_12_pollutants_date_time: string (nullable = true)
#  |-- data_station_12_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_12_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_12_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_12_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_12_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_12_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_13_pollutants_date_time: string (nullable = true)
#  |-- data_station_13_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_13_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_13_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_13_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_13_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_13_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_2_pollutants_date_time: string (nullable = true)
#  |-- data_station_2_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_2_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_2_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_2_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_2_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_2_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_date_time: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_3_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_date_time: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_5_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_date_time: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_10: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_20: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_7: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_7_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_8_pollutants_date_time: string (nullable = true)
#  |-- data_station_8_pollutants_pollutant_20: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_8_pollutants_pollutant_5: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_8_pollutants_pollutant_6001: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_9_pollutants_date_time: string (nullable = true)
#  |-- data_station_9_pollutants_pollutant_1: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_9_pollutants_pollutant_20: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_9_pollutants_pollutant_38: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_9_pollutants_pollutant_8: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- data_station_9_pollutants_pollutant_9: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- notation: string (nullable = true)
#  |    |-- value: string (nullable = true)

# %%
d.groupby(F.col("data_station_1_name_el")).count().show()
# Out:
# +----------------------+-----+
# |data_station_1_name_el|count|
# +----------------------+-----+
# |  Λευκωσία - Κυκλοφ...|    1|
# +----------------------+-----+

# %%
d.groupby('data_station_1_pollutants_pollutant_10')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-d0f73d25b4bb> in <module>
# ----> 1 d = d.toDF()
#       2 d.show(1)
#
# AttributeError: 'function' object has no attribute 'toDF'

# %%
df.write.mode('overwrite').parquet("df.parquet")

# %%
parquetDF = spark.read.parquet('df.parquet')
display(parquetDF)
# Out:
# DataFrame[data: struct<station_1:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_20:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_10:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_20:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_11:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_12:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_13:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_2:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:stri ...

# %%
parquetDF.createOrReplaceTempView("ParquetTable")
parkSQL = spark.sql("select * from ParquetTable where ")
parkSQL.show()
# Out:
# +--------------------+------+
# |                data|method|
# +--------------------+------+
# |[[35.151922469502...|   GET|
# +--------------------+------+

# %%
from pyspark.sql.functions import explode

explodeDF = parquetDF.select(explode("data").alias("d"))
#flattenDF = explodeDF.selectExpr("e.firstName", "e.lastName", "e.email", "e.salary")

explodeDF.show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/lib/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /usr/lib/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o363.select.
# : org.apache.spark.sql.AnalysisException: cannot resolve 'explode(`data`)' due to data type mismatch: input to function explode should be array or map type, not struct<station_1:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_20:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_10:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_20:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_11:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_12:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_13:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_2:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string ...
# 'Project [explode(data#31) AS d#43]
# +- Relation[data#31,method#32] parquet
#
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:42)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$$nestedInanonfun$checkAnalysis$1$2.applyOrElse(CheckAnalysis.scala:119)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$$nestedInanonfun$checkAnalysis$1$2.applyOrElse(CheckAnalysis.scala:110)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformUp$2(TreeNode.scala:280)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:69)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:280)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformUp$1(TreeNode.scala:277)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$mapChildren$1(TreeNode.scala:328)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:186)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:326)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:277)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.$anonfun$transformExpressionsUp$1(QueryPlan.scala:93)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.$anonfun$mapExpressions$1(QueryPlan.scala:105)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:69)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.transformExpression$1(QueryPlan.scala:105)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.recursiveTransform$1(QueryPlan.scala:116)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.$anonfun$mapExpressions$3(QueryPlan.scala:121)
# 	at scala.collection.TraversableLike.$anonfun$map$1(TraversableLike.scala:238)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at scala.collection.TraversableLike.map(TraversableLike.scala:238)
# 	at scala.collection.TraversableLike.map$(TraversableLike.scala:231)
# 	at scala.collection.AbstractTraversable.map(Traversable.scala:108)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.recursiveTransform$1(QueryPlan.scala:121)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.$anonfun$mapExpressions$4(QueryPlan.scala:126)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:186)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.mapExpressions(QueryPlan.scala:126)
# 	at org.apache.spark.sql.catalyst.plans.QueryPlan.transformExpressionsUp(QueryPlan.scala:93)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:110)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1$adapted(CheckAnalysis.scala:88)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:126)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:88)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:85)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:95)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:108)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:201)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:105)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed$lzycompute(QueryExecution.scala:58)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:56)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:48)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:78)
# 	at org.apache.spark.sql.Dataset.org$apache$spark$sql$Dataset$$withPlan(Dataset.scala:3411)
# 	at org.apache.spark.sql.Dataset.select(Dataset.scala:1341)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:750)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-22-c5d8d90f8cf9> in <module>
#       1 from pyspark.sql.functions import explode
#       2
# ----> 3 explodeDF = parquetDF.select(explode("data").alias("d"))
#       4 #flattenDF = explodeDF.selectExpr("e.firstName", "e.lastName", "e.email", "e.salary")
#       5
#
# /usr/lib/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1323         [Row(name=u'Alice', age=12), Row(name=u'Bob', age=15)]
#    1324         """
# -> 1325         jdf = self._jdf.select(self._jcols(*cols))
#    1326         return DataFrame(jdf, self.sql_ctx)
#    1327
#
# /usr/lib/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/lib/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: "cannot resolve 'explode(`data`)' due to data type mismatch: input to function explode should be array or map type, not struct<station_1:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_20:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_10:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_20:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_11:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_10:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_6001:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_12:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_13:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<code:string,description:string,notation:string,value:string>,pollutant_38:struct<code:string,description:string,notation:string,value:string>,pollutant_5:struct<code:string,description:string,notation:string,value:string>,pollutant_7:struct<code:string,description:string,notation:string,value:string>,pollutant_8:struct<code:string,description:string,notation:string,value:string>,pollutant_9:struct<code:string,description:string,notation:string,value:string>>,type_el:string,type_en:string>,station_2:struct<latitude:string,longitude:string,name_el:string,name_en:string,pollutants:struct<date_time:string,pollutant_1:struct<co ...

# %%
request_df = spark.createDataFrame([RestApiRequestRow("get", url, None, None)])

from pyspark.sql import Row
headers = {
    'content-type': "application/json"
}
body = json.dumps({
})

url = 'https://www.airquality.dli.mlsi.gov.cy/all_stations_data_PM'

RestApiRequestRow = Row("verb", "url", "headers", "body")
request_df = spark.createDataFrame([
            RestApiRequestRow("get", url, headers, body)
          ])

request_df.show()

request_df.take(20)
#request_df.write.json('gs://air_quality_cyprus/Data_Now.csv')

url = 'https://www.airquality.dli.mlsi.gov.cy/all_stations_data_PM'
from pyspark.sql.types import *
from pyspark.sql.functions import udf
            
udf_executeRestApi = udf(executeRestApi, schema)
#print(executeRestApi('get',url,None,None))
udf_executeRestApi

from pyspark.sql.functions import col
result_df = request_df.withColumn("result", udf_executeRestApi(col("verb"), col("url"), col("headers"), col("body")))
