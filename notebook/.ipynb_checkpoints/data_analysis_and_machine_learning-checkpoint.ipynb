# %%
import pandas as pd
import numpy as np


df_traffic = pd.read_csv("..\datasets\cyprus_airport_air_traffic\csv\CYPRUS_AIRPORTS_DAILY_AIR_TRAFFIC_2018_2021_TOTAL.csv")
df_traffic

df_quality = pd.read_csv("..\datasets\cyprus_air_quality\Data_Daily_All.csv")
df_quality
# Out:
#        Unnamed: 0        date  station_code  pollutant_id  \
# 0               0  2018-03-14             3             4
# 1               1  2018-04-21             3             4
# 2               2  2018-06-20             3             4
# 3               3  2018-10-18             3             4
# 4               4  2018-10-30             3             4
# ...           ...         ...           ...           ...
# 86193       86193  2020-07-25             2             3
# 86194       86194  2020-12-01             2             3
# 86195       86195  2020-02-05             3             3
# 86196       86196  2020-09-17             3             3
# 86197       86197  2020-10-16             3             3
#
#        mean_pollutant_value                station_name_en pollutant_code  \
# 0                  1.137500      Limassol -Traffic Station            SO2
# 1                  1.629167      Limassol -Traffic Station            SO2
# 2                  1.354167      Limassol -Traffic Station            SO2
# 3                  1.320833      Limassol -Traffic Station            SO2
# 4                  3.311111      Limassol -Traffic Station            SO2
# ...                     ...                            ...            ...
# 86193             13.586957  Nicosia - Residential Station            NOX
# 86194             61.233333  Nicosia - Residential Station            NOX
# 86195             29.113043      Limassol -Traffic Station            NOX
# 86196             54.066667      Limassol -Traffic Station            NOX
# 86197             38.629167      Limassol -Traffic Station            NOX
#
#       pollutant_name_en Unit_of_measurement_en
# 0        Sulfur Dioxide                  μg/m³
# 1        Sulfur Dioxide                  μg/m³
# 2        Sulfur Dioxide                  μg/m³
# 3        Sulfur Dioxide                  μg/m³
# 4        Sulfur Dioxide                  μg/m³
# ...                 ...                    ...
# 86193   Nitrogen Oxides                  μg/m³
# 86194   Nitrogen Oxides                  μg/m³
# 86195   Nitrogen Oxides                  μg/m³
# 86196   Nitrogen Oxides                  μg/m³
# 86197   Nitrogen Oxides                  μg/m³
#
# [86198 rows x 9 columns]

# %%
#pd.merge(df_traffic, df_quality,  how='left', left_on='[date,station_code]', right_on = '[date,station_code]')
df_quality_traffic = df_quality.merge(df_traffic, on=["date","station_code"])

# %%
# add visualization libraries
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

# %%
#df_quality_traffic.describe() 
df_quality_traffic.groupby(['station_name_en','pollutant_code']).mean()
# Out:
#                                             Unnamed: 0  station_code  \
# station_name_en           pollutant_code
# Larnaka - Traffic Station C6H6            41627.187543           5.0
#                           CO              43186.088980           5.0
#                           NO              42057.469541           5.0
#                           NO2             43616.364819           5.0
#                           NOX             42986.882957           5.0
#                           O3              44595.501027           5.0
#                           SO2             43000.212183           5.0
# Pafos - Traffic Station   C6H6            43962.856947          15.0
#                           CO              43362.611910          15.0
#                           NO              42811.219713          15.0
#                           NO2             43034.247775          15.0
#                           NOX             42726.261465          15.0
#                           O3              42881.939083          15.0
#                           SO2             41966.138261          15.0
#
#                                           pollutant_id  mean_pollutant_value  \
# station_name_en           pollutant_code
# Larnaka - Traffic Station C6H6                    45.0              0.985315
#                           CO                       6.0            373.863881
#                           NO                       1.0              7.613247
#                           NO2                      2.0             24.350633
#                           NOX                      3.0             35.978237
#                           O3                       5.0             63.890238
#                           SO2                      4.0              3.436789
# Pafos - Traffic Station   C6H6                    45.0              0.591301
#                           CO                       6.0            297.165247
#                           NO                       1.0              3.901547
#                           NO2                      2.0             13.245998
#                           NOX                      3.0             19.205960
#                           O3                       5.0             78.861970
#                           SO2                      4.0              1.451168
#
#                                           total_flights
# station_name_en           pollutant_code
# Larnaka - Traffic Station C6H6               152.111567
#                           CO                 152.111567
#                           NO                 152.111567
#                           NO2                152.111567
#                           NOX                152.111567
#                           O3                 152.111567
#                           SO2                152.111567
# Pafos - Traffic Station   C6H6                58.804928
#                           CO                  58.804928
#                           NO                  58.804928
#                           NO2                 58.804928
#                           NOX                 58.804928
#                           O3                  58.804928
#                           SO2                 58.804928

# %% [markdown]
# ##### Check the correlation between pollutants and find the most related to traffic in order to be used for further analysis
# The results have there is an interesting correlation around between round to 20-30% between air traffic and pollutants

# %%
col_val = ['mean_pollutant_value','total_flights']
#&(df_quality_traffic['station_name_en'] == 'Larnaka - Traffic Station')

pollutants = df_quality_traffic.pollutant_code.unique()
pvt = []
for p in pollutants:
    so2 = df_quality_traffic.loc[(df_quality_traffic['pollutant_code'] == p)].copy()
    corr = so2[col_val].corr(method='pearson',min_periods=3)['mean_pollutant_value'].total_flights
    pvt.append([p,corr])

pvt = pd.DataFrame(pvt, columns=['pollutant','correlation'])
pvt.set_index('pollutant').plot.bar()
pvt.sort_values('correlation')
# Out:
#   pollutant  correlation
# 5        O3    -0.133582
# 6      C6H6     0.119463
# 4        NO     0.145394
# 2        CO     0.222790
# 1       NOX     0.237071
# 3       NO2     0.294627
# 0       SO2     0.370445

# %%
# Out:
# array(['SO2', 'NOX', 'CO', 'NO2', 'NO', 'O3', 'C6H6'], dtype=object)
